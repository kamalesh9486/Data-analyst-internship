# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8bb68c11-00fd-4db1-b1c3-3b49d1311677" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bb68c11-00fd-4db1-b1c3-3b49d1311677">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
comp = pd.read_csv('company.csv')
comp.head()
# Out:
#    Year Total IT Companies New Startups  \
# 0  2015           5,00,000       25,000
# 1  2016           5,25,000       30,000
# 2  2017           5,50,000       35,000
# 3  2018           6,00,000       40,000
# 4  2019           6,50,000       45,000
#
#    Venture Capital Investment (Billion USD)  \
# 0                                        50
# 1                                        70
# 2                                        85
# 3                                       120
# 4                                       150
#
#    Global IT Market Size (Trillion USD) Growth Rate (%)  \
# 0                                   1.2               -
# 1                                   1.3             8.3
# 2                                   1.5            15.4
# 3                                   1.8              20
# 4                                   2.0            11.1
#
#         Key Trends/Technologies       Year.1 Total IT Companies.1  \
# ...

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Year                                      9 non-null      int64
#  1   Total IT Companies                        9 non-null      object
#  2   New Startups                              9 non-null      object
#  3   Venture Capital Investment (Billion USD)  9 non-null      int64
#  4   Global IT Market Size (Trillion USD)      9 non-null      float64
#  5   Growth Rate (%)                           9 non-null      object
#  6   Key Trends/Technologies                   9 non-null      object
#  7   Year.1                                    9 non-null      float64
#  8   Total IT Companies.1                      9 non-null      object
#  9   New Startups.1                            9 non-null      object
# ...

# %%
sns.jointplot(x='Year',y='New Startups',data=comp)

# %%
sns.barplot(x='Total IT Companies',y='New Startups',data=comp)
# Out:
# <Axes: xlabel='Total IT Companies', ylabel='New Startups'>

# %%
sns.displot(x='Year',y='New Startups',data=comp)
